# %%
students = [
    {"name": "Alice", "score": 85},
    {"name": "Bob", "score": 92},
    {"name": "Charlie", "score": 78},
    {"name": "David", "score": 95}
]
stu_score = sum([score['score'] for score in students])/len(students)
print(stu_score)
# Out:
# 87.5
